# %% [markdown]
# # Dominick's Data

# %% [markdown]
# ## Libraries

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent ))

# %%
from src.dominick import DominickDataLoader, DominickDataProcessor, DominickDataSaver

# %% [markdown]
# ## Loader

# %%
loader = DominickDataLoader()
df_upc_beer = loader.load("upcber.csv")
df_move_beer = loader.load("wber.csv")

# %% [markdown]
# ## Join

# %%
dataprocessor = DominickDataProcessor()
df_upc_move_beer = dataprocessor.join(df_upc_beer, df_move_beer, on="UPC")
df_upc_move_beer.head()
# Out:
#    COM_CODE  UPC     DESCRIP    SIZE  CASE    NITEM  STORE  WEEK  MOVE  QTY  \
# 0        27  294  BEER LIMIT  12/12O     2  9990180      2   298    11    1
# 1        27  294  BEER LIMIT  12/12O     2  9990180      2   299     9    1
# 2        27  294  BEER LIMIT  12/12O     2  9990180      2   300     6    1
# 3        27  294  BEER LIMIT  12/12O     2  9990180      2   301     5    1
# 4        27  294  BEER LIMIT  12/12O     2  9990180      2   302     1    1
#
#    PRICE SALE  PROFIT  OK         PRICE_HEX        PROFIT_HEX
# 0   2.62  NaN  -18.83   1  4004F5C28F5C28F6  C032D47AE147AE14
# 1   2.51  NaN   18.47   1  4004147AE147AE14  40327851EB851EB8
# 2   2.49  NaN   13.60   1  4003EB851EB851EC  402B333333333333
# 3   2.99  NaN  -67.89   1  4007EB851EB851EC  C050F8F5C28F5C29
# 4   2.49  NaN   13.60   1  4003EB851EB851EC  402B333333333333

# %% [markdown]
# ## Drop HEX

# %%
df_upc_move_beer = df_upc_move_beer.drop(columns=["PROFIT_HEX", "PRICE_HEX"])
df_upc_move_beer.head()
# Out:
#    COM_CODE  UPC     DESCRIP    SIZE  CASE    NITEM  STORE  WEEK  MOVE  QTY  \
# 0        27  294  BEER LIMIT  12/12O     2  9990180      2   298    11    1
# 1        27  294  BEER LIMIT  12/12O     2  9990180      2   299     9    1
# 2        27  294  BEER LIMIT  12/12O     2  9990180      2   300     6    1
# 3        27  294  BEER LIMIT  12/12O     2  9990180      2   301     5    1
# 4        27  294  BEER LIMIT  12/12O     2  9990180      2   302     1    1
#
#    PRICE SALE  PROFIT  OK
# 0   2.62  NaN  -18.83   1
# 1   2.51  NaN   18.47   1
# 2   2.49  NaN   13.60   1
# 3   2.99  NaN  -67.89   1
# 4   2.49  NaN   13.60   1

# %% [markdown]
# ## Renaming

# %%
rename_dict = {
    "COM_CODE": "category_code",
    "UPC": "upc_code",
    "DESCRIP": "product_description",
    "SIZE": "pack_size_text",
    "CASE": "units_per_case",
    "NITEM": "product_item_code",
    "STORE": "store_code",
    "WEEK": "week_id",
    "MOVE": "units_sold",
    "QTY": "units_per_deal",
    "PRICE": "total_price",
    "SALE": "promo_flag",
    "PROFIT": "gross_margin_pct",
    "OK": "exclude_flag",
}

df_upc_move_beer = dataprocessor.rename(df_upc_move_beer, rename_dict)
df_upc_move_beer.head()
# Out:
#    category_code  upc_code product_description pack_size_text  units_per_case  \
# 0             27       294          BEER LIMIT         12/12O               2
# 1             27       294          BEER LIMIT         12/12O               2
# 2             27       294          BEER LIMIT         12/12O               2
# 3             27       294          BEER LIMIT         12/12O               2
# 4             27       294          BEER LIMIT         12/12O               2
#
#    product_item_code  store_code  week_id  units_sold  units_per_deal  \
# 0            9990180           2      298          11               1
# 1            9990180           2      299           9               1
# 2            9990180           2      300           6               1
# 3            9990180           2      301           5               1
# 4            9990180           2      302           1               1
#
#    total_price promo_flag  gross_margin_pct  exclude_flag
# 0         2.62        NaN            -18.83             1
# 1         2.51        NaN             18.47             1
# 2         2.49        NaN             13.60             1
# 3         2.99        NaN            -67.89             1
# 4         2.49        NaN             13.60             1

# %% [markdown]
# ## New Ratios

# %%
df_new_ratios = dataprocessor.add_ratios(df_upc_move_beer)
df_new_ratios.head()
# Out:
#    category_code  upc_code product_description pack_size_text  units_per_case  \
# 0             27       294          BEER LIMIT         12/12O               2
# 1             27       294          BEER LIMIT         12/12O               2
# 2             27       294          BEER LIMIT         12/12O               2
# 3             27       294          BEER LIMIT         12/12O               2
# 4             27       294          BEER LIMIT         12/12O               2
#
#    product_item_code  store_code  week_id  units_sold  units_per_deal  \
# 0            9990180           2      298          11               1
# 1            9990180           2      299           9               1
# 2            9990180           2      300           6               1
# 3            9990180           2      301           5               1
# 4            9990180           2      302           1               1
#
#    total_price promo_flag  gross_margin_pct  exclude_flag  unit_price  \
# 0         2.62        NaN            -18.83             1        2.62
# 1         2.51        NaN             18.47             1        2.51
# 2         2.49        NaN             13.60             1        2.49
# 3         2.99        NaN            -67.89             1        2.99
# 4         2.49        NaN             13.60             1        2.49
#
#    sales_dolar  gross_margin_rate  gross_margin_dolar  cost_dolar
# 0        28.82            -0.1883               -5.43       34.25
# 1        22.59             0.1847                4.17       18.42
# 2        14.94             0.1360                2.03       12.91
# 3        14.95            -0.6789              -10.15       25.10
# 4         2.49             0.1360                0.34        2.15

# %% [markdown]
# ## Elasticity features

# %%
df_elasticity_features = dataprocessor.add_elasticity_features(df_new_ratios)
df_elasticity_features.head()
# Out:
#    category_code  upc_code product_description pack_size_text  units_per_case  \
# 0             27       294          BEER LIMIT         12/12O               2
# 1             27       294          BEER LIMIT         12/12O               2
# 2             27       294          BEER LIMIT         12/12O               2
# 3             27       294          BEER LIMIT         12/12O               2
# 4             27       294          BEER LIMIT         12/12O               2
#
#    product_item_code  store_code  week_id  units_sold  units_per_deal  ...  \
# 0            9990180           2      298          11               1  ...
# 1            9990180           2      299           9               1  ...
# 2            9990180           2      300           6               1  ...
# 3            9990180           2      301           5               1  ...
# 4            9990180           2      302           1               1  ...
#
#    price_per_liter avg_price_per_liter  on_promo  promo_B  promo_C  promo_S  \
# 0           0.6152              0.6152     False        0        0        0
# 1           0.5894              0.5894     False        0        0        0
# 2           0.5847              0.5847     False        0        0        0
# 3           0.7021              0.7021     False        0        0        0
# 4           0.5847              0.5847     False        0        0        0
#
#    log_units_sold  log_price_per_upc  log_liters_sold  log_price_per_liter
# 0        2.397895           0.963174         3.846833            -0.485808
# 1        2.197225           0.920283         3.646162            -0.528650
# 2        1.791759           0.912283         3.240697            -0.536656
# 3        1.609438           1.095273         3.058376            -0.353679
# 4        0.000000           0.912283         1.448938            -0.536656
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Save CSV

# %%
saver = DominickDataSaver()
saver.save("elasticity_features.csv", df_elasticity_features)
